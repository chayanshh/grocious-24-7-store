# %% [markdown]
# # Grade Deep EDA
#
# ### Grocious 24/7 Store Dataset

# %% [markdown]
# ### 1. Importing Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from datetime import datetime

# %% [markdown]
# ### 2. Importing Dataset

# %%
df = pd.read_csv('E:/EDA Project/Grocious24_7_data.csv')
df
# Out:
#      Order ID  Order Date   Ship Date      Customer Name Customer ID  \
# 0     ORD1000  2024-05-13  2024-05-16  Samantha Williams     CUST210
# 1     ORD1001  2025-01-16  2025-01-21     Charles Morgan     CUST114
# 2     ORD1002  2026-03-14  2026-03-16       Stephen Mayo     CUST473
# 3     ORD1003  2023-08-14  2023-08-18        Jose Wilson     CUST355
# 4     ORD1004  2023-08-20  2023-08-21     Maurice Rhodes     CUST148
# ...       ...         ...         ...                ...         ...
# 4995  ORD5995  2024-02-27  2024-03-01     Andrew Burgess     CUST343
# 4996  ORD5996  2026-05-04  2026-05-10        Casey Brown     CUST250
# 4997  ORD5997  2026-03-26  2026-04-01       Andrew Lopez     CUST695
# 4998  ORD5998  2023-08-14  2023-08-16    Jennifer Taylor     CUST577
# 4999  ORD5999  2023-06-05  2023-06-09        John Daniel     CUST245
#
#      Customer Segment  Product Name         Category Product ID  \
# 0      Small Business        RC Car             Toys   PROD4197
# 1            Consumer      Notebook  Office Supplies   PROD5462
# 2           Wholesale      Notebook  Office Supplies   PROD2775
# 3          VIP Member  Dining Table        Furniture   PROD6648
# 4      Small Business        Puzzle             Toys   PROD2891
# ...               ...           ...              ...        ...
# 4995        Wholesale    Headphones      Electronics   PROD8704
# 4996        Wholesale       Sweater         Clothing   PROD1690
# 4997   Small Business        RC Car             Toys   PROD9360
# 4998       VIP Member          Doll             Toys   PROD4603
# 4999        Wholesale      Sneakers         Clothing   PROD8685
#
#              Region  ... Sales Amount Cost Price   Profit  Stock Left  \
# 0              West  ...     16755.25   11483.04  5272.21          20
# 1        North-East  ...      6874.53    6036.74   837.79          45
# 2              East  ...      3052.92    1998.55  1054.37          33
# 3     International  ...     26423.59   18980.64  7442.95          34
# 4             South  ...      6573.31    4543.92  2029.39          32
# ...             ...  ...          ...        ...      ...         ...
# 4995        Central  ...      6834.96    4240.66  2594.30          26
# 4996        Central  ...      3115.84    2636.25   479.58          21
# 4997           West  ...     11103.84    7642.34  3461.50          19
# 4998           East  ...      1404.94    1059.97   344.97          45
# 4999        Central  ...      6441.85    5413.56  1028.29           4
#
#       Auto Reorder  Reorder Quantity               Supplier Name  \
# 0               No                 0  Lynch, Robinson and Fowler
# 1               No                 0               Simmons-Brown
# 2               No                 0              Fletcher-Meyer
# 3               No                 0               Koch and Sons
# 4               No                 0             Miller and Sons
# ...            ...               ...                         ...
# 4995            No                 0               Rush-Chandler
# 4996            No                 0                 Simpson-Lee
# 4997            No                 0                  Day-Warren
# 4998            No                 0                  Taylor PLC
# 4999           Yes                48                   Brown PLC
#
#                      Supplier Email  Payment Mode  Delivery Status
# 0              samuel16@salazar.net   Credit Card        Cancelled
# 1      newmanelizabeth@thompson.com          Cash         Returned
# 2               kwilliams@mayer.com           UPI          Pending
# 3       marquezbrian@villanueva.com    Debit Card          Pending
# 4               hallalexis@shaw.com    Debit Card        Cancelled
# ...                             ...           ...              ...
# 4995    rodrigueztodd@maldonado.biz          Cash        Cancelled
# 4996       zwood@thomas-morales.net           UPI          Pending
# 4997  crystal51@hernandez-tapia.com          Cash          Pending
# 4998              leslie21@dunn.biz           UPI         Returned
# 4999       ashleyking@hernandez.com   Credit Card          Pending
#
# [5000 rows x 26 columns]

# %% [markdown]
# ### 3. Dataset Head

# %%
df.head()
# Out:
#   Order ID  Order Date   Ship Date      Customer Name Customer ID  \
# 0  ORD1000  2024-05-13  2024-05-16  Samantha Williams     CUST210
# 1  ORD1001  2025-01-16  2025-01-21     Charles Morgan     CUST114
# 2  ORD1002  2026-03-14  2026-03-16       Stephen Mayo     CUST473
# 3  ORD1003  2023-08-14  2023-08-18        Jose Wilson     CUST355
# 4  ORD1004  2023-08-20  2023-08-21     Maurice Rhodes     CUST148
#
#   Customer Segment  Product Name         Category Product ID         Region  \
# 0   Small Business        RC Car             Toys   PROD4197           West
# 1         Consumer      Notebook  Office Supplies   PROD5462     North-East
# 2        Wholesale      Notebook  Office Supplies   PROD2775           East
# 3       VIP Member  Dining Table        Furniture   PROD6648  International
# 4   Small Business        Puzzle             Toys   PROD2891          South
#
#    ... Sales Amount Cost Price   Profit  Stock Left  Auto Reorder  \
# 0  ...     16755.25   11483.04  5272.21          20            No
# 1  ...      6874.53    6036.74   837.79          45            No
# 2  ...      3052.92    1998.55  1054.37          33            No
# 3  ...     26423.59   18980.64  7442.95          34            No
# 4  ...      6573.31    4543.92  2029.39          32            No
#
#    Reorder Quantity               Supplier Name                Supplier Email  \
# 0                 0  Lynch, Robinson and Fowler          samuel16@salazar.net
# 1                 0               Simmons-Brown  newmanelizabeth@thompson.com
# 2                 0              Fletcher-Meyer           kwilliams@mayer.com
# 3                 0               Koch and Sons   marquezbrian@villanueva.com
# 4                 0             Miller and Sons           hallalexis@shaw.com
#
#    Payment Mode  Delivery Status
# 0   Credit Card        Cancelled
# 1          Cash         Returned
# 2           UPI          Pending
# 3    Debit Card          Pending
# 4    Debit Card        Cancelled
#
# [5 rows x 26 columns]

# %% [markdown]
# ### 4. Dataset Tail

# %%
df.tail()
# Out:
#      Order ID  Order Date   Ship Date    Customer Name Customer ID  \
# 4995  ORD5995  2024-02-27  2024-03-01   Andrew Burgess     CUST343
# 4996  ORD5996  2026-05-04  2026-05-10      Casey Brown     CUST250
# 4997  ORD5997  2026-03-26  2026-04-01     Andrew Lopez     CUST695
# 4998  ORD5998  2023-08-14  2023-08-16  Jennifer Taylor     CUST577
# 4999  ORD5999  2023-06-05  2023-06-09      John Daniel     CUST245
#
#      Customer Segment Product Name     Category Product ID   Region  ...  \
# 4995        Wholesale   Headphones  Electronics   PROD8704  Central  ...
# 4996        Wholesale      Sweater     Clothing   PROD1690  Central  ...
# 4997   Small Business       RC Car         Toys   PROD9360     West  ...
# 4998       VIP Member         Doll         Toys   PROD4603     East  ...
# 4999        Wholesale     Sneakers     Clothing   PROD8685  Central  ...
#
#      Sales Amount Cost Price   Profit  Stock Left  Auto Reorder  \
# 4995      6834.96    4240.66  2594.30          26            No
# 4996      3115.84    2636.25   479.58          21            No
# 4997     11103.84    7642.34  3461.50          19            No
# 4998      1404.94    1059.97   344.97          45            No
# 4999      6441.85    5413.56  1028.29           4           Yes
#
#       Reorder Quantity  Supplier Name                 Supplier Email  \
# 4995                 0  Rush-Chandler    rodrigueztodd@maldonado.biz
# 4996                 0    Simpson-Lee       zwood@thomas-morales.net
# 4997                 0     Day-Warren  crystal51@hernandez-tapia.com
# 4998                 0     Taylor PLC              leslie21@dunn.biz
# 4999                48      Brown PLC       ashleyking@hernandez.com
#
#       Payment Mode  Delivery Status
# 4995          Cash        Cancelled
# 4996           UPI          Pending
# 4997          Cash          Pending
# 4998           UPI         Returned
# 4999   Credit Card          Pending
#
# [5 rows x 26 columns]

# %% [markdown]
# ### 5. Information of Dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order ID          5000 non-null   object
#  1   Order Date        5000 non-null   object
#  2   Ship Date         5000 non-null   object
#  3   Customer Name     5000 non-null   object
#  4   Customer ID       5000 non-null   object
#  5   Customer Segment  5000 non-null   object
#  6   Product Name      5000 non-null   object
#  7   Category          5000 non-null   object
#  8   Product ID        5000 non-null   object
#  9   Region            5000 non-null   object
#  10  Country           5000 non-null   object
#  11  State             5000 non-null   object
#  12  City              5000 non-null   object
#  13  Quantity          5000 non-null   int64
#  14  Unit Price        5000 non-null   float64
#  15  Discount (%)      5000 non-null   int64
#  16  Sales Amount      5000 non-null   float64
#  17  Cost Price        5000 non-null   float64
#  18  Profit            5000 non-null   float64
#  19  Stock Left        5000 non-null   int64
#  20  Auto Reorder      5000 non-null   object
#  21  Reorder Quantity  5000 non-null   int64
#  22  Supplier Name     5000 non-null   object
#  23  Supplier Email    5000 non-null   object
#  24  Payment Mode      5000 non-null   object
#  25  Delivery Status   5000 non-null   object
# dtypes: float64(4), int64(4), object(18)
# memory usage: 1015.8+ KB

# %% [markdown]
# ### 6. Data Types of Data

# %%
df.dtypes
# Out:
# Order ID             object
# Order Date           object
# Ship Date            object
# Customer Name        object
# Customer ID          object
# Customer Segment     object
# Product Name         object
# Category             object
# Product ID           object
# Region               object
# Country              object
# State                object
# City                 object
# Quantity              int64
# Unit Price          float64
# Discount (%)          int64
# Sales Amount        float64
# Cost Price          float64
# Profit              float64
# Stock Left            int64
# Auto Reorder         object
# Reorder Quantity      int64
# Supplier Name        object
# Supplier Email       object
# Payment Mode         object
# Delivery Status      object
# dtype: object

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### 8. Dataset Columns

# %%
df.columns
# Out:
# Index(['Order ID', 'Order Date', 'Ship Date', 'Customer Name', 'Customer ID',
#        'Customer Segment', 'Product Name', 'Category', 'Product ID', 'Region',
#        'Country', 'State', 'City', 'Quantity', 'Unit Price', 'Discount (%)',
#        'Sales Amount', 'Cost Price', 'Profit', 'Stock Left', 'Auto Reorder',
#        'Reorder Quantity', 'Supplier Name', 'Supplier Email', 'Payment Mode',
#        'Delivery Status'],
#       dtype='object')

# %% [markdown]
# ### 9. Shape Of Data

# %%
df.shape
# Out:
# (5000, 26)

# %% [markdown]
# ### 10. Describing the Dataset

# %%
df.describe(include = 'object')
# Out:
#        Order ID  Order Date   Ship Date Customer Name Customer ID  \
# count      5000        5000        5000          5000        5000
# unique     5000        1083        1087          4821         894
# top     ORD5999  2025-11-27  2024-02-24   James Smith     CUST114
# freq          1          13          17             4          15
#
#        Customer Segment Product Name     Category Product ID      Region  \
# count              5000         5000         5000       5000        5000
# unique                6           35            7       3832           7
# top      Small Business          Pen  Electronics   PROD2775  North-East
# freq                849          168          754          7         772
#
#        Country   State          City Auto Reorder Supplier Name  \
# count     5000    5000          5000         5000          5000
# unique     243      50          4292            2          4586
# top      Congo  Oregon  East Michael           No     Smith LLC
# freq        45     117             7         4078            10
#
#                   Supplier Email Payment Mode Delivery Status
# count                       5000         5000            5000
# unique                      5000            5               4
# top     ashleyking@hernandez.com  Net Banking        Returned
# freq                           1         1019            1284

# %% [markdown]
# ### 11. Checking the Null in Data

# %%
df.isnull().sum()
# Out:
# Order ID            0
# Order Date          0
# Ship Date           0
# Customer Name       0
# Customer ID         0
# Customer Segment    0
# Product Name        0
# Category            0
# Product ID          0
# Region              0
# Country             0
# State               0
# City                0
# Quantity            0
# Unit Price          0
# Discount (%)        0
# Sales Amount        0
# Cost Price          0
# Profit              0
# Stock Left          0
# Auto Reorder        0
# Reorder Quantity    0
# Supplier Name       0
# Supplier Email      0
# Payment Mode        0
# Delivery Status     0
# dtype: int64

# %% [markdown]
# # Data Analysis

# %% [markdown]
# ### Data Quality Check

# %%
print("\n=== DATA QUALITY ASSESSMENT ===")

print("\nMissing Values:\n")
missing_data = df.isnull().sum()
print(missing_data[missing_data > 0])

print(f"\nDuplicate Rows: {df.duplicated().sum()}")
# Out:
# === DATA QUALITY ASSESSMENT ===
#
# Missing Values:
#
# Series([], dtype: int64)
#
# Duplicate Rows: 0

# %% [markdown]
# ### Date Type Conversion

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'], format='%Y-%m-%d')
df['Ship Date'] = pd.to_datetime(df['Ship Date'], format='%Y-%m-%d')

print("\nDate Columns converted:\n")
print(f"Order Date: {df['Order Date'].dtype}")
print(f"Ship Date: {df['Ship Date'].dtype}")
# Out:
# Date Columns converted:
#
# Order Date: datetime64[ns]
# Ship Date: datetime64[ns]

# %% [markdown]
# ### UNIVARIANTE ANALYSIS

# %%
# Univariate Analysis is the simpliest form of statistical analysis. As the name suggests -"uni"
# means "one" and "variate" means "variable" - it is the analysis of a single

print("\n=== CATEGORICAL VARIABLES ===\n")

categorical_cols = ['Customer Segment', 'Category', 'Region', 'Payment Mode', 'Delivery Status', 'Auto Reorder']

for col in categorical_cols:
    print(f"\n--- {col} ---")
    print(df[col].value_counts())

    plt.figure(figsize=(4,4))
    counts = df[col].value_counts()
    ax = counts.plot(kind='bar', color='skyblue')

    min_val = counts.min()
    max_val = counts.max()
    
    plt.ylim(bottom=min_val * 0.95, top=max_val * 1.05) 
    plt.title(f'Distribution of {col}')
    plt.xticks(rotation = 30)
    plt.tight_layout()
    plt.show()
# Out:
# === CATEGORICAL VARIABLES ===
#
#
# --- Customer Segment ---
# Customer Segment
# Small Business    849
# Home Office       849
# Corporate         845
# VIP Member        829
# Wholesale         825
# Consumer          803
# Name: count, dtype: int64
# --- Category ---
# Category
# Electronics        754
# Office Supplies    739
# Toys               732
# Furniture          720
# Grocery            691
# Clothing           682
# Beauty             682
# Name: count, dtype: int64
# --- Region ---
# Region
# North-East       772
# International    753
# Central          740
# East             724
# West             679
# South            675
# North            657
# Name: count, dtype: int64
# --- Payment Mode ---
# Payment Mode
# Net Banking    1019
# Credit Card    1004
# Debit Card     1004
# Cash            991
# UPI             982
# Name: count, dtype: int64
# --- Delivery Status ---
# Delivery Status
# Returned     1284
# Cancelled    1281
# Pending      1220
# Delivered    1215
# Name: count, dtype: int64
# --- Auto Reorder ---
# Auto Reorder
# No     4078
# Yes     922
# Name: count, dtype: int64

# %% [markdown]
# ### Numerical Variable Analysis

# %%
print("\n=== NUMERICAL VARIABLES ===\n")

numerical_cols = ['Quantity', 'Unit Price', 'Discount (%)', 'Sales Amount', 'Cost Price', 'Profit', 'Stock Left', 'Reorder Quantity']

for cols in numerical_cols:
    print(f"\n--- {cols} ---")
    print(f"Mean: {df[cols].mean():.2f}")
    print(f"Median: {df[cols].median():.2f}")
    print(f"Std Dev: {df[cols].std():.2f}")
    print(f"Min: {df[cols].min():.2f}")
    print(f"Max: {df[cols].max():.2f}")

    # Visualization

    plt.figure(figsize=(6, 4))

    plt.subplot(1, 2, 1)
    df[cols].hist(bins=30, color='lightgreen', alpha=0.7)
    plt.title(f'Distribution of {cols}')

    plt.subplot(1, 2, 2)
    df.boxplot(column=cols)
    plt.title(f'Boxplot of {cols}')

    plt.tight_layout()
    plt.show()
# Out:
# === NUMERICAL VARIABLES ===
#
#
# --- Quantity ---
# Mean: 5.45
# Median: 5.00
# Std Dev: 2.85
# Min: 1.00
# Max: 10.00
# --- Unit Price ---
# Mean: 2548.97
# Median: 2574.96
# Std Dev: 1397.97
# Min: 101.06
# Max: 4999.07
# --- Discount (%) ---
# Mean: 10.09
# Median: 10.00
# Std Dev: 7.03
# Min: 0.00
# Max: 20.00
# --- Sales Amount ---
# Mean: 12517.00
# Median: 9876.40
# Std Dev: 10164.94
# Min: 106.80
# Max: 49960.18
# --- Cost Price ---
# Mean: 9403.25
# Median: 7294.43
# Std Dev: 7797.23
# Min: 69.57
# Max: 44656.62
# --- Profit ---
# Mean: 3113.75
# Median: 2245.78
# Std Dev: 2881.50
# Min: 18.93
# Max: 19682.55
# --- Stock Left ---
# Mean: 25.50
# Median: 26.00
# Std Dev: 14.62
# Min: 0.00
# Max: 50.00
# --- Reorder Quantity ---
# Mean: 6.50
# Median: 0.00
# Std Dev: 14.19
# Min: 0.00
# Max: 50.00

# %% [markdown]
# ### BIVARIATE ANALYSIS

# %%
# Bivariate Analysis is the statistical analysis of two variables at the same time. The core purpose is to investigate  the relationship between them.

print("\n=== SALES AND PROFIT BY CATEGORY ===\n")

category_performance = df.groupby('Category').agg({
    'Sales Amount': 'sum',
    'Profit': 'sum',
    'Order ID': 'count'
}).rename(columns={'Order ID': 'Order Count'})

category_performance['Profit Margin (%)'] = (category_performance['Profit'] / category_performance['Sales Amount']) * 100
print(category_performance, '\n\n')

# Visualization

fig, axes = plt.subplots(2, 2, figsize=(12, 10))

# Sales By Category
category_performance['Sales Amount'].plot(kind='bar', ax=axes[0, 0], color='blue', alpha=0.7)
axes[0, 0].set_title('Total Sales by Category')
axes[0, 0].tick_params(axis='x', rotation=30)


# Profit By Category
category_performance['Profit'].plot(kind='bar', ax=axes[0, 1], color='green', alpha=0.7)
axes[0, 1].set_title('Total Profit by Category')
axes[0, 1].tick_params(axis='x', rotation=30)

# Profit Margin
category_performance['Profit Margin (%)'].plot(kind='bar', ax=axes[1, 0], color='orange', alpha=0.7)
axes[1, 0].set_title('Profit Margin by Category (%)')
axes[1, 0].tick_params(axis='x', rotation=30)

# Order Count
category_performance['Order Count'].plot(kind='bar', ax=axes[1, 1], color='red', alpha=0.7)
axes[1, 1].set_title('Order Count by Category')
axes[1, 1].tick_params(axis='x', rotation=30)

plt.tight_layout()
plt.show()
# Out:
# === SALES AND PROFIT BY CATEGORY ===
#
#                  Sales Amount      Profit  Order Count  Profit Margin (%)
# Category
# Beauty             8433649.45  2158421.87          682          25.592976
# Clothing           8624534.39  2146541.84          682          24.888785
# Electronics        9158751.33  2241121.49          754          24.469727
# Furniture          9138238.64  2249954.19          720          24.621311
# Grocery            8713477.47  2193911.45          691          25.178368
# Office Supplies    9145448.08  2234255.88          739          24.430251
# Toys               9370905.09  2344542.80          732          25.019385

# %% [markdown]
# ### Regional Performance

# %%
print("\n=== REGIONAL PERFORMANCE ===\n")

region_performance = df.groupby('Region').agg({
    'Sales Amount': 'sum',
    'Profit': 'sum',
    'Order ID': 'count'
}).rename(columns={'Order ID': 'Order Count'})

region_performance['Profit Margin'] = (region_performance['Profit'] / region_performance['Sales Amount']) * 100
print(region_performance, '\n\n')

# Visualization

plt.figure(figsize=(12, 12))

plt.subplot(2, 2, 1)
region_performance['Sales Amount'].plot(kind='pie', autopct = '%1.1f%%')
plt.title('Sales Distribution by Region')

plt.subplot(2, 2, 2)
region_performance['Profit'].plot(kind='pie', autopct = '%1.1f%%')
plt.title('Profit Distribution by Region (%)')

plt.subplot(2, 2, 3)
region_performance['Profit Margin'].plot(kind='pie', autopct = '%1.1f%%')
plt.title('Profit Distribution by Region')

plt.subplot(2, 2, 4)
region_performance['Order Count'].plot(kind='pie', autopct = '%1.1f%%')
plt.title('Order Count by Region')

plt.tight_layout()
plt.show()
# Out:
# === REGIONAL PERFORMANCE ===
#
#                Sales Amount      Profit  Order Count  Profit Margin
# Region
# Central          9419786.12  2313572.11          740      24.560771
# East             8912508.14  2196799.25          724      24.648496
# International    9699276.84  2404247.57          753      24.787905
# North            8220798.04  2039143.99          657      24.804696
# North-East       9768144.94  2383379.13          772      24.399506
# South            8025315.95  2064467.66          675      25.724441
# West             8539174.42  2167139.81          679      25.378798

# %% [markdown]
# ### Time Series Analysis

# %%
print("\n=== REGIONAL PERFORMANCE ===\n")

# Exttact Time Components
df['Order Month'] = df['Order Date'].dt.to_period('M')
df['Order Year'] = df['Order Date'].dt.year

# Monthly Trend
monthly_trends = df.groupby('Order Month').agg({
    'Sales Amount': 'sum',
    'Profit': 'sum',
    'Order ID': 'count'
}).rename(columns={'Order ID': 'Order Count'})

print("Monthly Trends:")
print(monthly_trends.tail(10), '\n\n')

# Visualization
plt.figure(figsize=(10, 6))

plt.subplot(3, 1, 1)
monthly_trends['Sales Amount'].plot(kind='line', color='blue', marker='o')
plt.title('Monthly Sales Trend')
plt.ylabel('Sales Amount')
plt.grid(True)

plt.subplot(3, 1, 2)
monthly_trends['Profit'].plot(kind='line', color='green', marker='o')
plt.title('Monthly Profit Trend')
plt.ylabel('Profit')
plt.grid(True)

plt.subplot(3, 1, 3)
monthly_trends['Order Count'].plot(kind='line', color='red', marker='^')
plt.title('Monthly Order Count Trend')
plt.ylabel('Order Count')
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# === REGIONAL PERFORMANCE ===
#
# Monthly Trends:
#              Sales Amount     Profit  Order Count
# Order Month
# 2025-08        1587321.93  379496.27          129
# 2025-09        1805743.35  439994.93          140
# 2025-10        1688756.60  401864.94          127
# 2025-11        1753518.05  431255.54          140
# 2025-12        1777795.69  465438.86          156
# 2026-01        1893928.93  466284.88          146
# 2026-02        1535518.17  382727.89          123
# 2026-03        1955514.88  470115.63          152
# 2026-04        1776645.55  442159.22          154
# 2026-05        1204897.36  303298.41           99

# %% [markdown]
# ### Advance Analysis

# %%
print("\n=== CORRELATION ANALYSIS ===\n")

# Select numerical columns for correlation analysis
numerical_df = df[['Quantity', 'Unit Price', 'Discount (%)', 'Sales Amount', 'Cost Price', 'Profit']]

# Correlation Matrix
correlation_matrix = numerical_df.corr()
print("Correlation Matrix:")
print(correlation_matrix, '\n\n')

# Heatmap Visualization
plt.figure(figsize=(15, 10))

sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', center=0,
            square=True, linewidths=0.5)

plt.title('Correlation Heatmap')
plt.tight_layout()
plt.show()
# Out:
# === CORRELATION ANALYSIS ===
#
# Correlation Matrix:
#               Quantity  Unit Price  Discount (%)  Sales Amount  Cost Price  \
# Quantity      1.000000    0.015387      0.014639      0.647357    0.637393
# Unit Price    0.015387    1.000000      0.033817      0.677510    0.665038
# Discount (%)  0.014639    0.033817      1.000000     -0.063441   -0.060136
# Sales Amount  0.647357    0.677510     -0.063441      1.000000    0.982986
# Cost Price    0.637393    0.665038     -0.060136      0.982986    1.000000
# Profit        0.558892    0.590453     -0.061071      0.867733    0.761675
#
#                 Profit
# Quantity      0.558892
# Unit Price    0.590453
# Discount (%) -0.061071
# Sales Amount  0.867733
# Cost Price    0.761675
# Profit        1.000000

# %% [markdown]
# ### Customer Segemnt Analysis

# %%
print("\n=== CUSTOMER SEGMENT ANALYSIS ===\n")

segment_analysis = df.groupby('Customer Segment').agg({
    'Sales Amount': ['sum', 'mean'],
    'Profit': ['sum', 'mean'],
    'Order ID': 'count',
    'Discount (%)': 'mean'
}).round(2)

segment_analysis.columns = ['Total Sales', 'Total Profit', 'Order Count', 'Avg Discount', 'Avg Profit', 'Avg Sales']
print(segment_analysis, '\n\n')

# Visualization
fig, axes = plt.subplots(2, 2, figsize=(12, 10))

segment_analysis['Total Sales'].plot(kind='bar', ax=axes[0, 0], color='lightblue')
axes[0, 0].set_title('Total Sales by Customer Segment')
axes[0, 0].tick_params(axis='x', rotation=30)

segment_analysis['Total Profit'].plot(kind='bar', ax=axes[0, 1], color='lightgreen')
axes[0, 1].set_title('Total Profit by Customer Segment')
axes[0, 1].tick_params(axis='x', rotation=30)

segment_analysis['Avg Profit'].plot(kind='bar', ax=axes[1, 0], color='orange')
axes[1, 0].set_title('Average Profit by Customer Segment')
axes[1, 0].tick_params(axis='x', rotation=30)

segment_analysis['Avg Discount'].plot(kind='bar', ax=axes[1, 1], color='red')
axes[1, 1].set_title('Average Discount by Customer Segment')
axes[1, 1].tick_params(axis='x', rotation=30)

plt.tight_layout()
plt.show()
# Out:
# === CUSTOMER SEGMENT ANALYSIS ===
#
#                   Total Sales  Total Profit  Order Count  Avg Discount  \
# Customer Segment
# Consumer          10296405.58      12822.42   2567238.33       3197.06
# Corporate         10402739.43      12310.93   2619379.82       3099.86
# Home Office       10774343.06      12690.63   2700693.32       3181.03
# Small Business    10726006.35      12633.69   2646474.39       3117.17
# VIP Member        10257975.40      12373.91   2564888.50       3093.95
# Wholesale         10127534.63      12275.80   2470075.16       2994.03
#
#                   Avg Profit  Avg Sales
# Customer Segment
# Consumer                 803       9.89
# Corporate                845       9.66
# Home Office              849      10.04
# Small Business           849      10.35
# VIP Member               829      10.50
# Wholesale                825      10.06

# %% [markdown]
# ### Key Insights Summary

# %%
print("\n=== KEY INSIGHTS SUMMARY ===\n")

# Overall Metrix
total_sales = df['Sales Amount'].sum()
total_profit = df['Profit'].sum()
total_orders = df['Order ID'].nunique()
avg_profir_margin = (total_profit / total_sales) * 100

print("Overall Performance:\n")
print(f"Total Sales: ${total_sales:,.2f}")
print(f"Total Profit: ${total_profit:,.2f}")
print(f"Total Orders: {total_orders}")
print(f"Average Profit Margin: {avg_profir_margin:.2f}%")

# Top Perferming Categories
top_categories = df.groupby('Category')['Profit'].sum().sort_values(ascending=False)    
print("\nTop Performing Categories:\n")
for i, (category, profit) in enumerate(top_categories.items(), 1):
    print(f"{i}. {category}: ${profit:,.2f}")

# Regional Performance
best_region = df.groupby('Region')['Profit'].sum().idxmax()
print(f"\nBest Performing Region: {best_region}")

# Delivery Performance
delivery_stats = df['Delivery Status'].value_counts(normalize=True) * 100
print("\nDelivery Performance:\n")
for status, percent in delivery_stats.items():
    print(f"{status}: {percent:.1f}%")

# Customer Segments
best_segment = df.groupby('Customer Segment')['Profit'].sum().idxmax()
print(f"\nMost Profitable Customer Segment: {best_segment}")
# Out:
# === KEY INSIGHTS SUMMARY ===
#
# Overall Performance:
#
# Total Sales: $62,585,004.45
# Total Profit: $15,568,749.52
# Total Orders: 5000
# Average Profit Margin: 24.88%
#
# Top Performing Categories:
#
# 1. Toys: $2,344,542.80
# 2. Furniture: $2,249,954.19
# 3. Electronics: $2,241,121.49
# 4. Office Supplies: $2,234,255.88
# 5. Grocery: $2,193,911.45
# 6. Beauty: $2,158,421.87
# 7. Clothing: $2,146,541.84
#
# Best Performing Region: International
#
# Delivery Performance:
#
# Returned: 25.7%
# Cancelled: 25.6%
# Pending: 24.4%
# Delivered: 24.3%
#
# Most Profitable Customer Segment: Home Office

# %% [markdown]
# ### Export Result

# %%
analysis_results = {
    'total_sales': total_sales,
    'total_profit': total_profit,
    'total_orders': total_orders,
    'avg_profit_margin': avg_profir_margin,
    'top_categories': top_categories.index[0],
    'best_region': best_region,
    'delivery_performance': delivery_stats.index[0],
    'best_customer_segment': best_segment
}

# Convert to Dataframe and save
results_df = pd.DataFrame([analysis_results])
results_df.to_csv('E:/EDA Project/eda_analysis.csv', index=False)
print("\n Analysis summary saved to 'eda_analysis.csv'")
# Out:
#  Analysis summary saved to 'eda_analysis.csv'
